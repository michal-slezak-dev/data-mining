# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("UsersQ2023.csv", delimiter=";")
df.head()
# Out:
#    NoQ       Q  Users
# 0    1  Q3 '08    100
# 1    2  Q4 '08    148
# 2    3  Q1 '09    197
# 3    4  Q2 '09    242
# 4    5  Q3 '09    305

# %%
new_rows = pd.DataFrame([{"NoQ": np.nan, "Q": "Q1 '08"}, {"NoQ": np.nan, "Q": "Q2 '08"}])

# %%
df = pd.concat([new_rows, df], ignore_index=True)

# %%
df.head()
# Out:
#    NoQ       Q  Users
# 0  NaN  Q1 '08    NaN
# 1  NaN  Q2 '08    NaN
# 2  1.0  Q3 '08  100.0
# 3  2.0  Q4 '08  148.0
# 4  3.0  Q1 '09  197.0

# %%
df["NoQ"] = range(1, len(df) + 1)

# %%
df.head()
# Out:
#    NoQ       Q  Users
# 0    1  Q1 '08    NaN
# 1    2  Q2 '08    NaN
# 2    3  Q3 '08  100.0
# 3    4  Q4 '08  148.0
# 4    5  Q1 '09  197.0

# %%
df.to_csv("UsersQ2023_cleaned.csv")
